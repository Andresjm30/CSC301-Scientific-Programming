# %%
import time;
import math; 

def naiveAlgo(n):

    print("N= 10^" + str(math.log10(n)));
    startTime = time.time();

    partialSum=0;
    for i in range(0,n):
        partialSum = math.sqrt(19.0) + partialSum;
    endTime = time.time();

    exactSum = (n*math.sqrt(19.0));
    absError = abs(exactSum - partialSum);
    relError = absError/exactSum;
    elapsedTime =  endTime-startTime;
    print("Exact Sum: " + str(exactSum));
    print("Calculated Sum: "+ str(partialSum));
    print("Absolute Error: " + str(absError));
    print("Relative Error: " + str(relError));
    print("Elapsed time for summations: " + str(elapsedTime));
    print("__________________________________________");


def compSumAlgo(n):

    print("N= 10^" + str(math.log10(n)));
    sum = 0;
    carry = 0;
    startTime = time.time();
    for i in range(0,n):
        #Addition of square root of 19
        comp = math.sqrt(19.0) - carry;
        tmpSum = sum + comp;
        carry = (tmpSum - sum) - comp;

        sum=tmpSum;
    endTime = time.time();

    exactSum = (n * math.sqrt(19.0));
    absError = abs(exactSum - sum);
    relError = absError / exactSum;
    elapsedTime = endTime - startTime;
    print("Exact Sum: " + str(exactSum));
    print("Calculated Sum: " +str(sum))
    print("Absolute Error: " + str(absError));
    print("Relative Error: " + str(relError));
    print("Elapsed time for summations: " + str(elapsedTime));
    print("__________________________________________");

def runAlgos():

    size = [10**3,10**4,10**5,10**6,10**7,10**8,];
    for x in size:
        print("NAIVE ALGO: ");
        naiveAlgo(x);
        print("COMPENSATED ALGO:  ");
        compSumAlgo(x);

runAlgos();
# Out:
# NAIVE ALGO:
# N= 10^3.0
# Exact Sum: 4358.898943540674
# Calculated Sum: 4358.898943540652
# Absolute Error: 2.1827872842550278e-11
# Relative Error: 5.007657467006977e-15
# Elapsed time for summations: 0.0
# __________________________________________
# COMPENSATED ALGO:
# N= 10^3.0
# Exact Sum: 4358.898943540674
# Calculated Sum: 4358.898943540674
# Absolute Error: 0.0
# Relative Error: 0.0
# Elapsed time for summations: 0.0
# __________________________________________
# NAIVE ALGO:
# N= 10^4.0
# Exact Sum: 43588.98943540674
# Calculated Sum: 43588.98943540103
# Absolute Error: 5.704350769519806e-09
# Relative Error: 1.30866781804449e-13
# Elapsed time for summations: 0.0009975433349609375
# __________________________________________
# COMPENSATED ALGO:
# N= 10^4.0
# Exact Sum: 43588.98943540674
# Calculated Sum: 43588.98943540674
# Absolute Error: 0.0
# Relative Error: 0.0
# Elapsed time for summations: 0.0019941329956054688
# __________________________________________
# NAIVE ALGO:
# N= 10^5.0
# Exact Sum: 435889.8943540674
# Calculated Sum: 435889.8943536333
# Absolute Error: 4.341127350926399e-07
# Relative Error: 9.959229170383476e-13
# Elapsed time for summations: 0.013024091720581055
# __________________________________________
# COMPENSATED ALGO:
# N= 10^5.0
# Exact Sum: 435889.8943540674
# Calculated Sum: 435889.8943540674
# Absolute Error: 0.0
# Relative Error: 0.0
# Elapsed time for summations: 0.017961502075195312
# __________________________________________
# NAIVE ALGO:
# N= 10^6.0
# Exact Sum: 4358898.943540674
# Calculated Sum: 4358898.943627511
# Absolute Error: 8.683744817972183e-05
# Relative Error: 1.9921876901597763e-11
# Elapsed time for summations: 0.129652738571167
# __________________________________________
# COMPENSATED ALGO:
# N= 10^6.0
# Exact Sum: 4358898.943540674
# Calculated Sum: 4358898.943540674
# Absolute Error: 0.0
# Relative Error: 0.0
# Elapsed time for summations: 0.2044532299041748
# __________________________________________
# NAIVE ALGO:
# N= 10^7.0
# Exact Sum: 43588989.43540674
# Calculated Sum: 43588989.44469575
# Absolute Error: 0.009289011359214783
# Relative Error: 2.1310453579062438e-10
# Elapsed time for summations: 1.272803544998169
# __________________________________________
# COMPENSATED ALGO:
# N= 10^7.0
# Exact Sum: 43588989.43540674
# Calculated Sum: 43588989.43540674
# Absolute Error: 0.0
# Relative Error: 0.0
# Elapsed time for summations: 1.7831859588623047
# __________________________________________
# NAIVE ALGO:
# N= 10^8.0
# Exact Sum: 435889894.3540674
# Calculated Sum: 435889893.87809396
# Absolute Error: 0.4759734272956848
# Relative Error: 1.09195793125926e-09
# Elapsed time for summations: 13.334406852722168
# __________________________________________
# COMPENSATED ALGO:
# N= 10^8.0
# Exact Sum: 435889894.3540674
# Calculated Sum: 435889894.3540674
# Absolute Error: 0.0
# Relative Error: 0.0
# Elapsed time for summations: 18.493684768676758
# __________________________________________

# %% [markdown]
# Aanlysis for Assignment 2
#
# Naive Summation
# - This summation did contain higher error values than the other.
# - The values of errors varies from each trial but in the end it does decrease.
# - The increasing value of N does show continuous error for this summation.
# - The naive summation is quicker getting results than compensated summation, as you can see in the elapsed time in the exampples.
#
# Compensated Summation
# - the errors for this summation should not be decreasing based on the information from class but when testing the algorithm it quickly decreases leading to an underflow error to zero.
# - These examples could say that the compensated summation is superior to niave summation.
# - I think the results continue to be zero is because the n values are still too small to calcualte any error.
